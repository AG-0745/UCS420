# %% [markdown]
# <a href="https://colab.research.google.com/github/AG-0745/UCS420/blob/main/Cognitive_Ass_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 1.1

# %%
name = "Ani"
print(name)
print(name)
print(name)
# Out:
# Ani
# Ani
# Ani

# %% [markdown]
# Assignment 2.1

# %%
a = 10
b = 20
c = 30
d = a + b + c
print(a, " + ", b, " + ", c, " --> ", d)
# Out:
# 10  +  20  +  30  -->  60

# %% [markdown]
# Assignment 2.2

# %%
a = "Good"
b = " Morning"
c = " Everyone"
d = a + b + c
print(a, " + ", b, " + ", c, " --> ", d)
# Out:
# Good  +   Morning  +   Everyone  -->  Good Morning Everyone

# %% [markdown]
# Assignment 4.1

# %%
for i in range(1, 11):
    print(7, " * ", i, " = ", i * 7)
print()
for i in range(1, 11):
    print(9, " * ", i, " = ", i * 9)
# Out:
# 7  *  1  =  7
# 7  *  2  =  14
# 7  *  3  =  21
# 7  *  4  =  28
# 7  *  5  =  35
# 7  *  6  =  42
# 7  *  7  =  49
# 7  *  8  =  56
# 7  *  9  =  63
# 7  *  10  =  70
#
# 9  *  1  =  9
# 9  *  2  =  18
# 9  *  3  =  27
# 9  *  4  =  36
# 9  *  5  =  45
# 9  *  6  =  54
# 9  *  7  =  63
# 9  *  8  =  72
# 9  *  9  =  81
# 9  *  10  =  90

# %% [markdown]
# Assignment 4.2

# %%
n = int(input("Enter a number: "))
for i in range(1, 11):
    print(n, " * ", i, " = ", i * n)
# Out:
# Enter a number: 8
# 8  *  1  =  8
# 8  *  2  =  16
# 8  *  3  =  24
# 8  *  4  =  32
# 8  *  5  =  40
# 8  *  6  =  48
# 8  *  7  =  56
# 8  *  8  =  64
# 8  *  9  =  72
# 8  *  10  =  80

# %% [markdown]
# Assignment 4.3

# %%
n = int(input("Enter a number: "))
s = 0
for i in range(1, n + 1):
    s = s + i
print("Sum is --> ", s)
# Out:
# Enter a number: 15
# Sum is -->  120

# %% [markdown]
# Assignment 5.1

# %%
a = int(input("Enter First No: "))
b = int(input("Enter Second No: "))
c = int(input("Enter Third No: "))
print("Max --> ", max(a, b, c))
# Out:
# Enter First No: 7
# Enter Second No: 17
# Enter Third No: 14
# Max -->  17

# %% [markdown]
# Assignment 5.2

# %%
n = int(input("Enter a number: "))
s = 0
for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        s = s + i
print("Sum is --> ", s)
# Out:
# Enter a number: 126
# Sum is -->  189

# %% [markdown]
# Assignment 5.3

# %%
n = int(input("Enter a number: "))
s = 0
for i in range(2, n + 1):
    f = 0
    for j in range(2, i // 2 + 1):
        if i % j == 0:
            f = 1
            break
    if f == 0:
        s = s + i
print("Sum of primes is --> ", s)
# Out:
# Enter a number: 15
# Sum of primes is -->  41

# %% [markdown]
# Assignment 6.1

# %%
def AddOdd(n):
    s = 0
    for i in range(1, n + 1):
        if i % 2 != 0:
            s = s + i
    return s
n = int(input("Enter a number: "))
print("AddOdd(", n, ") --> ", AddOdd(n))
# Out:
# Enter a number: 7
# AddOdd( 7 ) -->  16

# %% [markdown]
# Assignment 6.2

# %%
def IsPrime(n):
    if n < 2:
        return 0
    for i in range(2, n // 2 + 1):
        if n % i == 0:
            return 0
    return 1
def AddPrimes(n):
    s = 0
    for i in range(1, n + 1):
        if IsPrime(i) == 1:
            s = s + i
    return s
n = int(input("Enter a number: "))
print("AddPrimes(", n, ") --> ", AddPrimes(n))
# Out:
# Enter a number: 81
# AddPrimes( 81 ) -->  791
